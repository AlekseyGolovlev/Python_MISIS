# %%
#1 - Средний балл и список остающих учеников
with open('students.txt', 'r', encoding = 'utf8') as fileprint:
    lines = fileprint.read().split('\n')
    i = 0
    s = 0
    print('Список отстающих учеников:')
    while i < len(lines):
        num = int(lines[i][-1])
        if num <= 3:
            print(f'{lines[i][0:-2]}, оценка {lines[i][-1]}')
        s += num
        i += 1
    print(f'\nСредний балл по студентам: {round(s/len(lines), 2)}')

# %%
#2 - Посчитать количество определенных слов в файле
import re
with open('schedule.txt', 'r', encoding = 'utf8') as file:
    text = file.read()
print(text, '\n')
sp = re.split(r'[\t\n ]', text)
sp_sort = [i for i in sp if not i == '']
lec = sp_sort.count('(лекц.)')
pract = sp_sort.count('(практ.)')
lab = sp_sort.count('(лаб.)')
print('Лекций:', lec)
print('Практических:', pract)
print('Лабораторных:', lab)

# %% [markdown]
# Том в устройстве C не имеет метки.
#  Серийный номер тома: 02C4-E1C1
#
#  Содержимое папки C:\Users\Aleksey\ДЗ Python
#
# 08.12.2021  15:20    <DIR>          .
# 05.12.2021  15:42    <DIR>          ..
# 04.12.2021  12:39    <DIR>          .ipynb_checkpoints
# 01.12.2021  18:52             3 182 Homework_1.ipynb
# 04.12.2021  12:42             2 977 Homework_2.ipynb
# 08.12.2021  15:20             7 048 Homework_3.ipynb
# 07.12.2021  17:14             6 643 Homework_4.ipynb
# 03.12.2021  18:36               250 schedule.txt
# 03.12.2021  14:52               308 students.txt
# 03.12.2021  20:11                32 test.txt
# 08.12.2021  15:21             1 135 text.txt
#                8 файлов         21 575 байт
#                3 папок  361 511 608 320 байт свободно

# %%
#5 - Напишите программу, которая принимает текст и выводит два слова: наиболее часто встречающееся и самое длинное.
import re

with open('text.txt', 'w', encoding = 'utf8') as f:
    text = input()
    f.write(text)

with open('text.txt', 'r', encoding = 'utf8') as f:
    text_read = f.read()

splitted = re.split(r'[-;,!.— ]', text_read)
sort_sp = [i for i in splitted if not i == '']

for i,j in enumerate(sort_sp):
    print(f'Частота встречаемости слова {j}:', round(sort_sp.count(j) / len(sort_sp) * 100, 2))
print(f'Слов в строке {i+1}')

# %% [markdown]
# Варкалось. Хливкие шорьки Пырялись по наве, И хрюкотали зелюки, Как мюмзики в мове.
#
# О, бойся Бармаглота, сын! Он так свирлеп и дик! А в глу́ше ры́мит исполин — Злопастный Брандашмыг!
#
# Но взял он меч, и взял он щит, Высоких полон дум. В глущобу путь его лежит Под дерево Тумтум.
#
# Он стал под дерево и ждёт. И вдруг граахнул гром — Летит ужасный Бармаглот И пылкает огнём!
#
# Раз-два, раз-два! Горит трава, Взы-взы — стрижает меч, Ува! Ува! И голова Барабардает с плеч!
#
# О светозарный мальчик мой! Ты победил в бою! О храброславленный герой, Хвалу тебе пою!
#
# Варкалось. Хливкие шорьки Пырялись по наве. И хрюкотали зелюки, Как мюмзики в мове.
